# %% [markdown]
# # Web scraping project of Jumia products

# %% [markdown]
# ## Importing Libraries
# For this web scraping project, the libries used would be
# * Requests to send a get request to Jumia site to get the html code of the particular page
# * Beautiful soup to parse the page gotten.
# * Pandas to store the data scraped
# * Array for imputation of array as an argument of a function

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from array import *

# %% [markdown]
# First order of business in this scraping project was to get the major category of products in Jumia as shown in the code below

# %%
def get_category():
    topic_url= 'https://jumia.com'
    try:
        response=requests.get(topic_url)
    except:
        pass
    if response:
        print(response.status_code)
        page_content=response.text
        doc = BeautifulSoup(page_content, 'html.parser')
        category_links=doc.find_all('a',{'class':'itm', 'role':"menuitem"})
        category_hrefs=[]
        categories=[]
        if category_links:
            for link in category_links:
                try:
                    if link["href"].startswith('https'):
                        category_hrefs.append(link["href"])
                    else:
                        category_hrefs.append('https://jumia.com.ng' + link["href"])
                    categories.append(link.text)
                except:
                    pass
        else:
            pass
    return pd.DataFrame({'category_href':category_hrefs,'categories':categories})

# %%
category=get_category()
# Out:
# 200

# %%
category
# Out:
#                                       category_href        categories
# 0               https://www.jumia.com.ng/groceries/       Supermarket
# 1               https://jumia.com.ng/health-beauty/   Health & Beauty
# 2                 https://jumia.com.ng/home-office/     Home & Office
# 3              https://jumia.com.ng/phones-tablets/  Phones & Tablets
# 4                   https://jumia.com.ng/computing/         Computing
# 5                 https://jumia.com.ng/electronics/       Electronics
# 6   https://jumia.com.ng/category-fashion-by-jumia/           Fashion
# 7               https://jumia.com.ng/baby-products/     Baby Products
# 8                 https://jumia.com.ng/video-games/            Gaming
# 9              https://jumia.com.ng/sporting-goods/    Sporting Goods
# 10                 https://jumia.com.ng/automobile/        Automobile

# %% [markdown]
# #### Next was to get the list of products in a specific category.The function below takes the link of the category as an argument. A while loop was implemented so as to scrape each page of the category. Jumia's pagination only goes as far as 50 pages and 40 items per page, so the highest number of products in a category that can be gotten is around 2000 products.

# %%
def category_lists(category_href):
    category_page= category_href
    list_hrefs=[]
    prod_name= []
    price=[]
    rating=[]
    rating_count= []
    while True:
        cat_res=requests.get(category_page)
        print(cat_res.status_code)
        page_content=cat_res.text
        cat_doc= BeautifulSoup(page_content,'html.parser')
        cat_list=cat_doc.find_all('div',{'class': 'info'})
        cat_list=[lists.parent for lists in cat_list]
        
        for lists in cat_list:
            try:
                href=lists['href']
                if href.startswith('https'):
                    list_hrefs.append(href)
                else:
                    list_hrefs.append('https://jumia.com.ng' + href)
                prod_tag=lists.find('h3',{'class':'name'})
                if prod_tag:
                    prod_name.append(prod_tag.text)
                else:
                    prod_name.append('no name')
                stars_tag=lists.find('div',{'class':'rev'})
                if stars_tag:
                    rating.append(stars_tag.text.split('(')[0])
                    rating_count.append(stars_tag.text.split('(')[1])
                else:
                    rating.append('nil_rating')
                    rating_count.append('Nil count')
                price_tag=lists.find('div',{'class':'prc'})
                if price_tag:
                    price.append(price_tag.text)
                else:
                    price.append('no price')
            except:
                pass
        next_page=cat_doc.find('a', {'aria-label': 'Next Page'})
        header='https://jumia.com.ng'
        if next_page == None:
            break
        else: 
            category_page= header + next_page['href']
    
    return pd.DataFrame({'product links':list_hrefs,'product name':prod_name,
                         'price':price, 'product_rating':rating,'rating count':rating_count})

# %%
health_category_link=category['category_href'][1]
health_category_link
# Out:
# 'https://jumia.com.ng/health-beauty/'

# %%
health_category_list=category_lists(health_category_link)
health_category_list
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#                                           product links  \
# 0     https://jumia.com.ng/andrea-fast-powerful-oil-...
# 1     https://jumia.com.ng/andrea-fast-powerful-oil-...
# 2     https://jumia.com.ng/uv-aqua-rich-watery-essen...
# 3     https://jumia.com.ng/braided-ghana-weaving-hai...
# 4     https://jumia.com.ng/narciso-rodriguez-for-him...
# ...                                                 ...
# 1995  https://jumia.com.ng/generic-buttercup-setting...
# 1996  https://jumia.com.ng/acne-stress-control-toner...
# 1997  https://jumia.com.ng/beauty-formulas-tea-tree-...
# 1998  https://jumia.com.ng/kirkland-signature-minoxi...
# 1999  https://jumia.com.ng/tea-tree-5in1-beauty-esse...
#
#                                            product name     price  \
# 0     Andrea Fast Powerful Oil Hair And Quick Beard ...   ₦ 1,000
# 1     Andrea Fast Powerful Oil Hair And Quick Beard ...   ₦ 1,000
# 2     Biore UV Aqua Rich Watery Essence Sunscreen SP...   ₦ 2,800
# 3                        Braided Ghana Weaving Hair Wig  ₦ 10,350
# 4       Narciso Rodriguez For Him Men Perfume 100ML EDT  ₦ 51,500
# ...                                                 ...       ...
# 1995  Buttercup Setting Powder/Finishing Powder For ...   ₦ 2,999
# 1996               Neutrogena Acne Stress Control Toner   ₦ 7,600
# 1997           Beauty Formulas Tea Tree Cleansing Wipes   ₦ 2,699
# 1998  Kirkland Signature Minoxidil 5% Hair & Beard G...   ₦ 7,300
# 1999                 Tea Tree 5in1-Beauty Essential Set   ₦ 7,199
#
#      product_rating rating count
# 0        nil_rating    Nil count
# 1        2 out of 5           2)
# 2      4.5 out of 5         247)
# 3        nil_rating    Nil count
# 4        nil_rating    Nil count
# ...             ...          ...
# 1995   4.2 out of 5          31)
# 1996   4.3 out of 5          11)
# 1997   4.5 out of 5           2)
# 1998   3.9 out of 5          13)
# 1999   4.2 out of 5           6)
#
# [2000 rows x 5 columns]

# %% [markdown]
# #### The link from category to list of products in a category is different from the link if the individual wishes to search just a particular product on jumia search bar. To that effect, a function was drawm up which takes the search criteria as an argument and returns a dataframe of the list of products in the individual product or category searched for. Just like the list of products in a specific category, the list of product from the search field is 40 per page and the maximum of 50 pages which amounts to a maximum of 2000 products for each scraping.

# %%
def list_frm_search(search_crt):
    search_crt=str(search_crt)
    if len(search_crt)==1:
        search_crt=search_crt
    else:
        search_crt='+'.join(search_crt.split(' '))
    search_href='https://www.jumia.com.ng/catalog/?q=' + search_crt
    list_hrefs=[]
    prod_name= []
    price=[]
    rating=[]
    rating_count= []
    while True:
        search_res=requests.get(search_href)
        page_content=search_res.text
        search_doc= BeautifulSoup(page_content,'html.parser')
        search_list=search_doc.find_all('div',{'class': 'info'})
        search_list=[lists.parent for lists in search_list]
        
        for lists in search_list:
            try:
                href=lists['href']
                if href.startswith('https'):
                    list_hrefs.append(href)
                else:
                    list_hrefs.append('https://jumia.com.ng' + href)
                prod_tag=lists.find('h3',{'class':'name'})
                if prod_tag:
                    prod_name.append(prod_tag.text)
                else:
                    prod_name.append('no name')
                stars_tag=lists.find('div',{'class':'rev'})
                if stars_tag:
                    rating.append(stars_tag.text.split('(')[0])
                    rating_count.append(stars_tag.text.split('(')[1])
                else:
                    rating.append('nil_rating')
                    rating_count.append('Nil count')
                price_tag=lists.find('div',{'class':'prc'})
                if price_tag:
                    price.append(price_tag.text)
                else:
                    price.append('no price')
            except:
                pass
        next_page=search_doc.find('a', {'aria-label': 'Next Page'})
        header='https://jumia.com.ng'
        if next_page == None:
            break
        else: 
            search_href= header + next_page['href']
    
    return pd.DataFrame({'product links':list_hrefs,'product name':prod_name,
                         'price':price, 'product_rating':rating,'rating count':rating_count})

# %%
Phone_search_list=list_frm_search('Phones')
Phone_search_list
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#                                           product links  \
# 0     https://jumia.com.ng/xiaomi-redmi-note-12-6.67...
# 1     https://jumia.com.ng/samsung-galaxy-a03-core-a...
# 2     https://jumia.com.ng/xiaomi-a1-plus-6.52-4g-lt...
# 3     https://jumia.com.ng/infinix-hot-20i-x665c-6.6...
# 4     https://jumia.com.ng/samsung-galaxy-a14-6.6-4g...
# ...                                                 ...
# 1995  https://jumia.com.ng/generic-adapter-dac-to-3....
# 1996  https://jumia.com.ng/generic-rj45-to-adapter-l...
# 1997  https://jumia.com.ng/generic-replacement-new-t...
# 1998  https://jumia.com.ng/generic-switch-on-off-pow...
# 1999  https://jumia.com.ng/generic-new-for-ipad-mini...
#
#                                            product name      price  \
# 0     XIAOMI Redmi Note 12 6.67'' 8GB 128GB ROM Andr...  ₦ 150,000
# 1     Samsung Galaxy A03 Core Android 11 - 6.5 Inche...   ₦ 56,000
# 2     XIAOMI A1 Plus, 6.52" 4G LTE, 2GB/32GB Memory,...   ₦ 51,510
# 3      Infinix HOT 20i- (X665C) 6.6" 2GB/64GB 4G - Blue   ₦ 68,478
# 4     Samsung Galaxy A14 - 6.6" (4GB RAM, 128GB ROM)...  ₦ 121,570
# ...                                                 ...        ...
# 1995  Adapter DAC To 3.5mm MFi Lightning For IPhones...   ₦ 31,000
# 1996  RJ45 To Adapter Lightning Ethernet For IPhone1...   ₦ 31,700
# 1997  Replacement New Touch Screen Digitizer For Hua...   ₦ 21,849
# 1998  Switch On Off Power Volume Button Flex Cable F...   ₦ 23,172
# 1999  New For IPad Mini 1 Screen IPad Mini 2 Touch S...   ₦ 22,091
#
#      product_rating rating count
# 0        nil_rating    Nil count
# 1      4.4 out of 5          58)
# 2      4.5 out of 5          95)
# 3        4 out of 5           8)
# 4      4.1 out of 5          17)
# ...             ...          ...
# 1995     nil_rating    Nil count
# 1996     nil_rating    Nil count
# 1997     nil_rating    Nil count
# 1998     nil_rating    Nil count
# 1999     nil_rating    Nil count
#
# [2000 rows x 5 columns]

# %% [markdown]
# #### Lastly, the reviews from each of the product from the search will be scraped for their reviews

# %%
def get_reviews(links):
    seller_perm=[]
    seller_followers_perm = []
    seller_rating_perm = []
    pr_revs=[]
    pr_rev_rating=[]
    pr_rev_date=[]
    pr_rev_title=[]
    name_perm=[]
    desc_perm=[]
    for link_hrefs in links:
        prod_res=requests.get(link_hrefs)
        page_content= prod_res.text
        pr_doc=BeautifulSoup(page_content, 'html.parser')
        seller_info=pr_doc.find('h2',{'class':"-m -fs14"})
        if seller_info:
            seller_info=seller_info.parent
            if seller_info:
                seller_info=seller_info.parent
                if seller_info:
                    seller=seller_info.find('p', {'class': '-m -pbs'})
                    seller_rating= seller_info.find('bdo', {'class': '-m -prxs'})
                    seller_followers= seller_info.find('p', {'data-followers': 'true'})
                    if seller:
                        seller=seller.text
                    else:
                        seller='No seller'
                    if seller_rating:
                        seller_rating=seller_rating.text
                    else:
                        seller_rating='No seller rating'
                    if seller_followers:
                        seller_followers=seller_followers.text
                    else:
                        seller_followers='No seller followers'
        prod_name=pr_doc.find('h1', {'class':"-fs20 -pts -pbxs"})
        if prod_name:
            name=prod_name.text
        else:
            name='No Product name'
        prod_desc=pr_doc.find('div',{'class':"markup -mhm -pvl -oxa -sc"})
        if prod_desc:
            desc=prod_desc.text
        else:
            desc='No Product Description'
        rev_link=pr_doc.find('a',{'class':'btn _def _ti -mhs -fsh0'})
        if rev_link== None:
            if seller:
                seller_perm.append(seller)
            else:
                seller_perm.append('Nil seller')
            if seller_followers:
                seller_followers_perm.append(seller_followers)
            else:
                seller_followers_perm.append('Nil seller followers')
            if seller_rating:
                seller_rating_perm.append(seller_rating)
            else:
                seller_rating_perm.append('Nil seller rating')
            if name:
                name_perm.append(name)
            else:
                name_perm.append('Nil prod name')
            if desc:
                desc_perm.append(desc)
            else:
                desc_perm.append('Nil prod description')
            pr_revs.append('Nil Review')
            pr_rev_rating.append('Nil rating')
            pr_rev_date.append('Nil review date')
            pr_rev_title.append('Nil review title')
        else:
            rev_link='https://jumia.com.ng' + rev_link['href']
            while True:
                rev_res=requests.get(rev_link)
                page_content=rev_res.text
                rev_doc=BeautifulSoup(page_content, 'html.parser')
                reviews=rev_doc.find_all('article', {'class': '-pvs -hr _bet'})
                for rev in reviews:
                    if seller:
                        seller_perm.append(seller)
                    else:
                        seller_perm.append('Nil seller')
                    if seller_followers:
                        seller_followers_perm.append(seller_followers)
                    else:
                        seller_followers_perm.append('Nil seller followers')
                    if seller_rating:
                        seller_rating_perm.append(seller_rating)
                    else:
                        seller_rating_perm.append('Nil seller rating')
                    if name:
                        name_perm.append(name)
                    else:
                        name_perm.append('Nil prod name')
                    if desc:
                        desc_perm.append(desc)
                    else:
                        desc_perm.append('Nil prod description')
                    rev_title= rev.find('h3',{'class':"-m -fs16 -pvs"})
                    if rev_title:
                        pr_rev_title.append(rev_title.text)
                    else:
                        rev_title.append('No title')
                    rev_text= rev.find('p',{'class':"-pvs"})
                    if rev_text:
                        pr_revs.append(rev_text.text)
                    else:
                        pr_revs.append('Nil text')
                    rev_rating=rev.find('div',{'class':"stars _m _al -mvs"})
                    if rev_rating:
                        pr_rev_rating.append(rev_rating.text)
                    else:
                        pr_rev_rating.append('Nil Rating')
                    rev_date=rev.find('span',{'class':"-prs"})
                    if rev_date:
                        pr_rev_date.append(rev_date.text)
                    else:
                        pr_rev_date.append('Nil date')
                next_page=rev_doc.find('a', {'aria-label': 'Next Page'})
                if next_page == None:
                    break
                else:
                    rev_link= 'https://jumia.com.ng' + next_page['href']
    return pd.DataFrame({'seller':seller_perm, 'seller followers': seller_followers_perm,
                         'product name': name_perm,'description': desc_perm,
                         'seller rating': seller_rating_perm,'review rating':pr_rev_rating,
                         'review date': pr_rev_date, 'review title': pr_rev_title,'reviews': pr_revs,
                        })

# %%
product_list=Phone_search_list['product links'].values.tolist()
arr=product_list[:2]

# %%
arr
# Out:
# ['https://jumia.com.ng/xiaomi-redmi-note-12-6.67-8gb-128gb-rom-android-13-onyx-gray-229788869.html',
#  'https://jumia.com.ng/samsung-galaxy-a03-core-android-11-6.5-inches-screen-display-2gb-ram-32gb-internal-storage-5000mah-4g-lte-onyx-black-125729493.html']

# %%
get_reviews(arr)
# Out:
#                                     seller seller followers  \
# 0                    HiTaste Communication   1276 Followers
# 1   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 2   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 3   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 4   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 5   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 6   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 7   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 8   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 9   SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 10  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 11  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 12  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 13  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 14  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 15  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 16  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 17  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 18  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 19  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 20  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 21  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
# 22  SUN WORLDWIDE DISTRIBUTIONS LIMITED-AC    640 Followers
#
#                                          product name  \
# 0   XIAOMI Redmi Note 12 6.67'' 8GB 128GB ROM Andr...
# 1   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 2   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 3   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 4   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 5   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 6   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 7   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 8   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 9   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 10  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 11  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 12  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 13  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 14  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 15  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 16  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 17  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 18  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 19  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 20  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 21  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
# 22  Samsung Galaxy A03 Core Android 11 - 6.5 Inche...
#
#                                           description seller rating  \
# 0   All Redmi Note 12 models feature an impressive...          100%
# 1   Maximize your view to the fullestExpand your v...           94%
# 2   Maximize your view to the fullestExpand your v...           94%
# 3   Maximize your view to the fullestExpand your v...           94%
# 4   Maximize your view to the fullestExpand your v...           94%
# 5   Maximize your view to the fullestExpand your v...           94%
# 6   Maximize your view to the fullestExpand your v...           94%
# 7   Maximize your view to the fullestExpand your v...           94%
# 8   Maximize your view to the fullestExpand your v...           94%
# 9   Maximize your view to the fullestExpand your v...           94%
# 10  Maximize your view to the fullestExpand your v...           94%
# 11  Maximize your view to the fullestExpand your v...           94%
# 12  Maximize your view to the fullestExpand your v...           94%
# 13  Maximize your view to the fullestExpand your v...           94%
# 14  Maximize your view to the fullestExpand your v...           94%
# 15  Maximize your view to the fullestExpand your v...           94%
# 16  Maximize your view to the fullestExpand your v...           94%
# 17  Maximize your view to the fullestExpand your v...           94%
# 18  Maximize your view to the fullestExpand your v...           94%
# 19  Maximize your view to the fullestExpand your v...           94%
# 20  Maximize your view to the fullestExpand your v...           94%
# 21  Maximize your view to the fullestExpand your v...           94%
# 22  Maximize your view to the fullestExpand your v...           94%
#
#    review rating      review date               review title  \
# 0     Nil rating  Nil review date           Nil review title
# 1     5 out of 5       08-05-2023                  I love it
# 2     4 out of 5       01-05-2023                  beautiful
# 3     5 out of 5       28-04-2023    samsung galaxy A03 core
# 4     5 out of 5       17-04-2023                       Good
# 5     4 out of 5       13-04-2023        I like the products
# 6     4 out of 5       10-04-2023     About Galaxy A03 phone
# 7     4 out of 5       05-04-2023          Its Nice And Fast
# 8     4 out of 5       31-03-2023                       GOOD
# 9     4 out of 5       21-03-2023                       good
# 10    2 out of 5       20-02-2023                Samsung A03
# 11    4 out of 5       17-02-2023  Good for the money but...
# 12    5 out of 5       23-01-2023                  Very cool
# 13    5 out of 5       23-01-2023              This is good!
# 14    5 out of 5       13-01-2023                  I like it
# 15    5 out of 5       28-12-2022                    Superb!
# 16    3 out of 5       05-12-2022              Camera issues
# 17    4 out of 5       30-11-2022                  I like it
# 18    4 out of 5       16-11-2022               good quality
# 19    5 out of 5       14-11-2022                  Best Ever
# 20    4 out of 5       18-07-2022         good for the price
# 21    5 out of 5       07-07-2022                  i like it
# 22    5 out of 5       29-06-2022               Great device
#
#                                               reviews
# 0                                          Nil Review
# 1     A very good product with a long lasting battery
# 2   Its beautiful and battery last long,i like and...
# 3   This mobile phone from Samsung is one of the b...
# 4                                           Great buy
# 5   Even though it's a bit heavy but I love the gr...
# 6                                        Product okay
# 7      Make the earpiece clearer,  louder and softer.
# 8   Only that it doesn't have fingerprint as speci...
# 9                            It has been working fine
# 10  Its nice\nThe person that i ordered it for lov...
# 11  I wish to have a software update that will res...
# 12                                   Functioning well
# 13                        Nice product, great quality
# 14                                     It's authentic
# 15       Great battery and good performance generally
# 16  The only problem is tha camera. It doesn't wor...
# 17              But I can't find the earpiece\r\nwhy?
# 18                                             Camera
# 19                                          I love it
# 20  Very good phone but i get to reboot it sometim...
# 21                                          i like it
# 22  Being using it for a week now and it's running...
